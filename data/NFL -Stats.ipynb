# %%
import pandas as pd 

data = pd.read_csv("nfl_football_team_stats.csv") 

data
# Out:
#       Year      Date  GameNumber GameLocation                 Team  TeamScore  \
# 0     2010    9/9/10           1         Away    Minnesota Vikings          9
# 1     2010    9/9/10           1         Home   New Orleans Saints         14
# 2     2010   9/12/10           1         Away    Arizona Cardinals         17
# 3     2010   9/12/10           1         Away      Atlanta Falcons          9
# 4     2010   9/12/10           1         Away    Carolina Panthers         18
# ...    ...       ...         ...          ...                  ...        ...
# 4088  2017  11/26/17          11         Home  San Francisco 49ers         13
# 4089  2017  11/27/17          11         Away       Houston Texans         16
# 4090  2017  11/27/17          11         Home     Baltimore Ravens         23
# 4091  2017  11/30/17          12         Away  Washington Redskins         14
# 4092  2017  11/30/17          12         Home       Dallas Cowboys         38
#
# ...

# %%
data.groupby("Year").count()
# Out:
#       Date  GameNumber  GameLocation  Team  TeamScore  Opponent  \
# Year
# 2010   534         534           534   534        534       534
# 2011   535         535           535   535        535       535
# 2012   534         534           534   534        534       534
# 2013   534         534           534   534        534       534
# 2014   534         534           534   534        534       534
# 2015   534         534           534   534        534       534
# 2016   534         534           534   534        534       534
# 2017   354         354           354   354        354       354
#
#       OppponentScore  Result  PassingAttempts  PassingCompletions  ...  \
# Year                                                               ...
# 2010             534     534              534                 534  ...
# 2011             535     535              535                 535  ...
# 2012             534     534              534                 534  ...
# ...
